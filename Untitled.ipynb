# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
# Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv("./temp-files/Online_game-1.csv")
df = pd.DataFrame(data)
df
# Out:
#      Rank                                               Name Platform    Year  \
# 0     181      Dragon Quest VIII: Journey of the Cursed King      PS2  2004.0
# 1     182                                         Diablo III       PC  2012.0
# 2     183                                Super Mario Bros. 3      GBA  2003.0
# 3     184                            New Super Mario Bros. U     WiiU  2012.0
# 4     185                     Super Mario Land 3: Wario Land       GB  1994.0
# ..    ...                                                ...      ...     ...
# 814   996                           Tom Clancy's Ghost Recon       XB  2002.0
# 815   997                                 State of Emergency      PS2  2002.0
# 816   998                                  BioShock Infinite      PS3  2013.0
# 817   999                                 Hitman: Absolution     X360  2012.0
# 818  1000  2 Games in 1 Double Pack: The Incredibles / Fi...      GBA  2007.0
#
# ...

# %%
df['Global_Sales'].value_counts().index[0:3]
# Out:
# Index([1.76, 1.86, 2.79], dtype='float64', name='Global_Sales')
